# %%
import pandas as pd
import numpy as np
import seaborn as sns
# homes = pd.read_csv('homes.csv')

# %%
from read_path_module import read_data_relative_path

homes = read_data_relative_path(relative_dataset_path = './data/kaggle/train.csv',
                        data_type='csv'
                       )

homes.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %% [markdown]
# # LotFrontage: (0, 1, 2) vs. else

# %%
homes.LotFrontage.agg(['max','min'])
homes['LotFrontage_bin']= pd.cut(homes['LotFrontage'],15, labels = False)
homes.groupby('LotFrontage_bin').agg(['count','mean','max','min'])['SalePrice']
# Out:
#                  count           mean     max     min
# LotFrontage_bin
# 0.0                 98  142027.551020  324000   55000
# 1.0                206  156627.150485  538000   35311
# 2.0                544  166969.623162  501837   34900
# 3.0                250  217209.188000  556581   82500
# 4.0                 66  268402.681818  755000   85000
# 5.0                 22  191312.727273  320000   81000
# 6.0                  8  193187.500000  375000   52500
# 7.0                  4  414431.250000  745000  235000
# 8.0                  1  259000.000000  259000  259000
# 14.0                 2  201000.000000  242000  160000

# %%
cat = 'LotFrontage_bin'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # LotArea: Discussion

# %%
homes.LotArea.agg(['max','min'])
homes['LotArea_bin']= pd.cut(homes['LotArea'],100, labels = False)
homes.groupby('LotArea_bin').agg(['count','mean','std','max','min'])['SalePrice']
# Out:
#              count           mean            std     max     min
# LotArea_bin
# 0               76  138735.526316   39191.439082  234000   75000
# 1               98  150169.979592   54468.558173  328900   39300
# 2              210  139327.914286   46632.999709  392500   37900
# 3              431  162946.533643   55486.713354  392000   34900
# 4              324  192627.675926   69189.191759  466500   61000
# 5              161  227903.086957   97367.919169  611657   80000
# 6               66  278528.924242  109563.432306  745000  133500
# 7               33  207570.727273   84173.398845  501837   81000
# 8               10  225312.400000   94150.201911  437154  129000
# 9               14  245510.000000  165446.026105  755000  113000
# 10               5  287025.000000  110989.225265  475000  181000
# 11               7  179735.714286   78718.891815  335000  112000
# 12               2  213500.000000   40305.086528  242000  185000
# ...

# %% [markdown]
# # Yearbuilt: maintain as numerical

# %%
homes['YearBuilt_bin']= pd.cut(homes['YearBuilt'],20, labels = False)
homes.groupby('YearBuilt_bin').agg(['count','mean','std','max','min'])['SalePrice']
# Out:
#                count           mean            std     max     min
# YearBuilt_bin
# 0                  2  108000.000000   19798.989873  122000   94000
# 1                  7  170425.571429   78388.137563  295000  100000
# 2                  4  216725.000000  173534.441826  475000  107500
# 3                  2  215500.000000  154856.385080  325000  106000
# 4                 13  121571.230769   30139.529299  163000   79000
# 5                 24  118710.583333   36594.194258  240000   37900
# 6                 66  129283.515152   46444.304239  256000   34900
# 7                 56  125161.250000   42522.094110  234000   55000
# 8                 33  146934.363636   65995.312851  359100   55000
# 9                 65  133844.938462   58922.995495  381000   52000
# 10                20  128390.000000   47605.405487  259500   39300
# 11                93  132331.494624   37891.934835  256000   35311
# 12               131  146569.000000   37788.484306  335000   60000
# ...

# %%
homes.groupby('YearBuilt_bin').agg(['mean'])['SalePrice'].plot.bar()

# %% [markdown]
# # YearRemodAdd:

# %%
homes['YearRemodAdd_bin']= pd.cut(homes['YearBuilt'],20, labels = False)

homes.groupby('YearRemodAdd_bin').agg(['count','mean','std','max','min'])['SalePrice']
# Out:
#                   count           mean            std     max     min
# YearRemodAdd_bin
# 0                     2  108000.000000   19798.989873  122000   94000
# 1                     7  170425.571429   78388.137563  295000  100000
# 2                     4  216725.000000  173534.441826  475000  107500
# 3                     2  215500.000000  154856.385080  325000  106000
# 4                    13  121571.230769   30139.529299  163000   79000
# 5                    24  118710.583333   36594.194258  240000   37900
# 6                    66  129283.515152   46444.304239  256000   34900
# 7                    56  125161.250000   42522.094110  234000   55000
# 8                    33  146934.363636   65995.312851  359100   55000
# 9                    65  133844.938462   58922.995495  381000   52000
# 10                   20  128390.000000   47605.405487  259500   39300
# 11                   93  132331.494624   37891.934835  256000   35311
# ...

# %%
homes.groupby('YearRemodAdd_bin').agg(['mean'])['SalePrice'].plot.bar()

# %% [markdown]
# # MasVnrArea: potentially drop? linked to sq ft?

# %%
homes.MasVnrArea.agg(['max','min'])
homes['MasVnrArea_bin']= pd.cut(homes['MasVnrArea'],40, labels = False)
homes.groupby('MasVnrArea_bin').agg(['mean','median'])['SalePrice'].sort_values(by='MasVnrArea_bin', ascending = True).plot.bar()

# %%
homes.groupby('MasVnrArea_bin').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='MasVnrArea_bin', ascending = False)
# Out:
#                          mean  median  count            std     min     max
# MasVnrArea_bin
# 39.0            239000.000000  239000      1            NaN  239000  239000
# 34.0            625000.000000  625000      1            NaN  625000  625000
# 29.0            755000.000000  755000      1            NaN  755000  755000
# 28.0            176000.000000  176000      1            NaN  176000  176000
# 27.0            244000.000000  244000      1            NaN  244000  244000
# 26.0            159950.000000  159950      1            NaN  159950  159950
# 25.0            438780.000000  438780      1            NaN  438780  438780
# 24.0            336000.000000  336000      1            NaN  336000  336000
# 23.0            325625.000000  325625      2   85736.697219  265000  386250
# 22.0            172500.000000  172500      1            NaN  172500  172500
# 21.0            461077.000000  461077      2   33832.231053  437154  485000
# ...

# %%
sns.distplot(homes['MasVnrArea_bin'])

# %% [markdown]
# # BsmtFinSF2:

# %%
homes.BsmtFinSF2.agg(['max','min'])
homes['BsmtFinSF2_bin']= pd.cut(homes['BsmtFinSF2'],10, labels = False)
homes.groupby('BsmtFinSF2_bin').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
# Out:
#                          mean  median  count           std     min     max
# BsmtFinSF2_bin
# 9               301000.000000  301000      1           NaN  301000  301000
# 7               221321.428571  213250      7  31466.488221  170000  270000
# 6               205531.250000  193000      4  71187.865817  142125  294000
# 5               211350.000000  191500      8  79644.621377  124000  375000
# 0               182020.406038  164700   1325  80739.605040   34900  755000
# 1               166441.860465  154000     43  58831.013981   85000  402000
# 3               172226.785714  151000     28  90065.024331   75500  555000
# 2               152887.320000  147000     25  41718.872263   62383  287000
# 4               147536.842105  139000     19  29795.100465  110000  238000

# %% [markdown]
# # BsmtUnfSF:

# %%
homes.BsmtUnfSF.agg(['max','min'])
homes['BsmtUnfSF_bin']= pd.cut(homes['BsmtUnfSF'],10, labels = False)
homes.groupby('BsmtUnfSF_bin').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
# Out:
#                         mean    median  count            std     min     max
# BsmtUnfSF_bin
# 9              393849.333333  386250.0      3   18836.124902  380000  415298
# 8              347039.333333  372500.0      9   94341.768087  171000  485000
# 7              256104.583333  240000.0     24  110202.986340  135000  582933
# 6              222776.849057  225000.0     53   57313.892538  110000  438780
# 5              208188.486111  193189.5     72   68333.729078   60000  466500
# 4              187345.283019  166000.0    106   89771.759630   67000  755000
# 1              187479.407514  165250.0    346   81878.498776   35311  745000
# 3              166222.833333  165200.0    216   59872.932537   55000  555000
# 2              174229.664062  155000.0    256   84493.156428   37900  625000
# 0              164435.704000  145900.0    375   68566.527822   34900  611657

# %%
homes.TotalBsmtSF.agg(['max','min'])
homes['TotalBsmtSF_bin']= pd.cut(homes['TotalBsmtSF'],20, labels = False)
homes.groupby('TotalBsmtSF_bin').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='TotalBsmtSF_bin', ascending = False)
# Out:
#                           mean  median  count            std     min     max
# TotalBsmtSF_bin
# 19               160000.000000  160000      1            NaN  160000  160000
# 10               363437.500000  357000      4  162651.259730  184750  555000
# 8                372250.000000  372250      2  133289.628254  278000  466500
# 7                462627.111111  386250      9  201146.320282  244000  755000
# 6                342862.232558  360000     43  101822.139565  137900  625000
# 5                256549.615385  248614    130   78205.819390  110000  582933
# 4                212772.082305  194500    243   62833.777199   60000  446261
# 3                170232.252381  151450    420   56724.873321   67000  475000
# 2                148342.183128  140000    486   44775.831402   34900  381000
# 1                124328.282051  125500     78   40901.444801   35311  242000
# 0                103078.568182  100900     44   30004.158310   39300  198500

# %% [markdown]
# # 1stFlrSF:

# %%
homes['1stFlrSF'].agg(['max','min'])
homes['1stFlrSF_bin']= pd.cut(homes['1stFlrSF'],20, labels = False)
homes.groupby('1stFlrSF_bin').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='1stFlrSF_bin', ascending = False)
# Out:
#                        mean  median  count            std     min     max
# 1stFlrSF_bin
# 19            160000.000000  160000      1            NaN  160000  160000
# 13            430000.000000  430000      1            NaN  430000  430000
# 12            184750.000000  184750      1            NaN  184750  184750
# 11            287000.000000  287000      1            NaN  287000  287000
# 10            315041.333333  278000      3  136753.636607  200624  466500
# 9             610581.400000  611657      5  151937.584240  386250  755000
# 8             291620.937500  265250     16   97365.286202  137900  501837
# 7             335939.147059  359550     34   93826.579160  144000  556581
# 6             256300.336283  249700    113   96946.639192  100000  625000
# 5             225954.386905  214750    168   64081.772464  118000  475000
# 4             187712.682028  176000    217   59413.349905   60000  392000
# ...

# %%
homes.groupby('1stFlrSF_bin').agg(['mean'])['SalePrice'].sort_values(by='1stFlrSF_bin', ascending = True).plot.bar()

# %% [markdown]
# # LowQualFinSF

# %%
homes.LowQualFinSF.agg(['max','min'])
homes['LowQualFinSF_bin']= pd.cut(homes['LowQualFinSF'],5, labels = False)
homes.groupby('LowQualFinSF_bin').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='LowQualFinSF_bin', ascending = False)
# Out:
#                            mean  median  count            std     min     max
# LowQualFinSF_bin
# 4                 178062.500000  123500      8  127382.281090   85000  475000
# 3                 156750.000000  154750      8   50151.199957  103000  235000
# 2                 108750.000000  108750      2   34294.678888   84500  133000
# 1                 115350.000000  123450      4   24540.918212   79500  135000
# 0                 181354.343533  163700   1438   79319.978147   34900  755000

# %% [markdown]
# # GrLivArea:

# %%
homes.GrLivArea.agg(['max','min'])
homes['GrLivArea_bin']= pd.cut(homes['GrLivArea'],10, labels = False)
homes.groupby('GrLivArea_bin').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='GrLivArea_bin', ascending = False)
# Out:
#                         mean  median  count            std     min     max
# GrLivArea_bin
# 9              160000.000000  160000      1            NaN  160000  160000
# 8              184750.000000  184750      1            NaN  184750  184750
# 7              750000.000000  750000      2    7071.067812  745000  755000
# 6              550000.000000  550000      2  106066.017178  475000  625000
# 5              337550.000000  339550     12  116057.207680  197000  538000
# 4              309794.245614  302000     57   89594.544830  136000  582933
# 3              251725.486772  240000    189   85276.901540   90000  611657
# 2              195065.800000  185000    535   56154.578343   79000  394432
# 1              137714.909747  136750    554   33020.653124   37900  254000
# 0              105242.467290  110000    107   27762.323855   34900  155900

# %%
homes.groupby('GrLivArea_bin').agg(['mean'])['SalePrice'].sort_values(by='GrLivArea_bin', ascending = True).plot.bar()

# %% [markdown]
# # BsmtFullBath: 0 v 1+

# %%
homes.groupby('BsmtFullBath').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                        mean  median  count           std     min     max
# BsmtFullBath
# 2             213063.066667  188000     15  87308.196346  108959  385000
# 1             202522.918367  178800    588  88895.866415   35311  745000
# 3             179000.000000  179000      1           NaN  179000  179000
# 0             165521.640187  154150    856  68137.819610   34900  755000

# %% [markdown]
# # BsmtHalfBath: drop

# %%
homes.groupby('BsmtHalfBath').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                        mean    median  count           std     min     max
# BsmtHalfBath
# 0             181230.330189  163250.0   1378  79303.224623   34900  745000
# 1             176098.125000  159000.0     80  82901.003355   91500  755000
# 2             160850.500000  160850.5      2  47164.729412  127500  194201

# %% [markdown]
# # FullBath: 0&1 v 2&3

# %%
homes.groupby('FullBath').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                    mean  median  count            std     min     max
# FullBath
# 3         347822.909091  320000     33  165185.455377  170000  755000
# 2         213009.825521  196750    768   72446.809159   55000  611657
# 0         165200.888889  145000      9  106083.806001   35311  385000
# 1         134751.440000  132375    650   41565.080488   34900  423000

# %%
cat = 'FullBath'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %%
# HalfBath: discuss?

# %%
homes.groupby('HalfBath').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                    mean    median  count           std     min     max
# HalfBath
# 1         212721.960748  189000.0    535  88629.242668   61000  755000
# 0         162534.884995  143000.0    913  67450.336922   34900  555000
# 2         162028.916667  159243.5     12  30315.705676  108959  201800

# %%
cat = 'HalfBath'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # BedroomAbvGr:

# %%
homes.groupby('BedroomAbvGr').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='BedroomAbvGr', ascending = False)
# Out:
#                        mean  median  count            std     min     max
# BedroomAbvGr
# 8             200000.000000  200000      1            NaN  200000  200000
# 6             143779.000000  141000      7   26455.384839  119000  200000
# 5             180819.047619  161500     21   68472.480743   81000  320000
# 4             220421.253521  193500    213  109510.516383   64500  755000
# 3             181056.870647  169945    804   63793.924903   40000  451950
# 2             158197.659218  137250    358   78197.106241   34900  611657
# 1             173162.420000  145250     50  102975.067584   35311  501837
# 0             221493.166667  202500      6  106675.888935  108959  385000

# %% [markdown]
# # KitchenAbvGr: 1 v rest

# %%
homes.groupby('KitchenAbvGr').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                        mean  median  count           std     min     max
# KitchenAbvGr
# 1             183388.790230  165550   1392  80265.344315   34900  755000
# 2             131096.153846  133900     65  31483.474549   55000  206300
# 0             127500.000000  127500      1           NaN  127500  127500
# 3             109500.000000  109500      2   4949.747468  106000  113000

# %%
cat = 'KitchenAbvGr'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # TotRmsAbvGrd

# %%
homes.groupby('TotRmsAbvGrd').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='TotRmsAbvGrd', ascending = False)
# Out:
#                        mean    median  count            std     min     max
# TotRmsAbvGrd
# 14            200000.000000  200000.0      1            NaN  200000  200000
# 12            280971.454545  200000.0     11  165510.918593  142953  582933
# 11            318022.000000  311738.5     18  148216.975202  106000  611657
# 10            296279.170213  285000.0     47  155027.992122   90000  755000
# 9             252988.173333  252000.0     75   83131.922273   98000  501837
# 8             213427.529412  200000.0    187   73985.715639   81000  466500
# 7             196666.784195  184100.0    329   64404.686026   55000  465000
# 6             161303.296020  155000.0    402   48707.372941   37900  374000
# 5             141550.749091  130250.0    275   49656.905700   52000  392500
# 4             122844.628866  120500.0     97   41661.805370   34900  260000
# 3             111217.647059  100000.0     17   33108.103904   60000  155900
# ...

# %%
homes.groupby('TotRmsAbvGrd').agg(['mean','median'])['SalePrice'].sort_values(by='TotRmsAbvGrd', ascending = True).plot.bar()

# %%
homes.groupby('TotRmsAbvGrd').agg(['mean'])['SalePrice'].sort_values(by='TotRmsAbvGrd', ascending = False).plot.bar()

# %% [markdown]
# # Fireplaces: no fireplace v rest

# %%
homes.groupby('Fireplaces').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                      mean  median  count            std     min     max
# Fireplaces
# 3           252000.000000  205000      5   93313.986090  160000  360000
# 2           240588.539130  206900    115  117451.800525  100000  755000
# 1           211843.909231  189975    650   79531.825318   60000  625000
# 0           141331.482609  135000    690   44389.786884   34900  342643

# %% [markdown]
# # FireplaceQu: no fireplace v poor v else

# %%
homes.GarageYrBlt.agg(['max','min'])
homes['GarageYrBlt_bin']= pd.cut(homes['GarageYrBlt'],10, labels = False)
homes.groupby('GarageYrBlt_bin').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                           mean  median  count           std     min     max
# GarageYrBlt_bin
# 9.0              239049.925373  220000    402  83754.980243  105900  611657
# 8.0              214619.616505  191000    206  91146.392961   81000  755000
# 7.0              165903.966387  148000    119  56506.242220   68400  385000
# 6.0              155838.711538  149900    208  44598.519582   75000  345000
# 0.0              147316.666667  134450      6  46840.171506  106000  240000
# 5.0              146408.364532  140000    203  42089.670333   35311  375000
# 2.0              145371.200000  137450     45  49700.249334   60000  315000
# 3.0              144300.980392  126000     51  60581.968019   58500  359100
# 4.0              136887.471698  132000    106  40084.631956   55993  265979
# 1.0              130108.696970  125500     33  51583.348474   40000  256000

# %% [markdown]
# # GarageCars

# %%
homes.groupby('GarageCars').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='GarageCars', ascending = False)
# Out:
#                      mean  median  count            std     min     max
# GarageCars
# 4           192655.800000  200000      5   52621.839745  123000  265979
# 3           309636.121547  295000    181  106832.925939   81000  755000
# 2           183851.663835  177750    824   51617.144258   55993  430000
# 1           128116.688347  128000    369   30412.386890   35311  266500
# 0           103317.283951  100000     81   32815.023389   34900  200500

# %%
homes.GarageArea.agg(['max','min'])
homes['GarageArea_bin']= pd.cut(homes['GarageArea'],10, labels = False)
homes.groupby('GarageArea_bin').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                          mean    median  count            std     min     max
# GarageArea_bin
# 7               349379.700000  353647.0     10  113663.941367  186700  582933
# 8               322612.333333  385000.0      3  217244.357479   81000  501837
# 5               301592.971698  295038.5    106  120510.350722   87000  755000
# 6               271184.614035  274900.0     57   82655.395730  105000  446261
# 4               206219.825000  196500.0    240   70068.890644   89471  555000
# 9               193764.333333  168000.0      3   51708.283827  160000  253293
# 3               181458.000000  175950.0    500   50666.524118   55993  430000
# 2               142471.187713  138800.0    293   39130.137471   35311  359100
# 1               127791.167665  124500.0    167   34553.675145   40000  266500
# 0               103317.283951  100000.0     81   32815.023389   34900  200500

# %%
# WoodDeckSF:

# %%
homes.WoodDeckSF.agg(['max','min'])

homes['WoodDeckSF_bin']= pd.cut(homes['WoodDeckSF'],10, labels = False)

homes.groupby('WoodDeckSF_bin').agg(['count','mean'])['SalePrice']
# Out:
#                 count           mean
# WoodDeckSF_bin
# 0                 826  158281.250605
# 1                 286  197182.566434
# 2                 198  221682.454545
# 3                  82  212913.170732
# 4                  38  225576.973684
# 5                  17  223235.294118
# 6                   7  265210.000000
# 7                   3  250372.666667
# 8                   2  149450.000000
# 9                   1  385000.000000

# %% [markdown]
# # OpenPorchSF

# %%
homes['OpenPorchSF'].agg(['max','min'])

homes['OpenPorchSF_bin']= pd.cut(homes['OpenPorchSF'],5, labels = False)

homes.groupby('OpenPorchSF_bin').agg(['count','mean','std'])['SalePrice']
# Out:
#                  count           mean            std
# OpenPorchSF_bin
# 0                 1249  174916.977582   76879.165622
# 1                  168  215670.601190   82399.081693
# 2                   36  222329.250000   96369.786179
# 3                    4  205306.750000   66071.692493
# 4                    3  205300.000000  151549.892775

# %% [markdown]
# # EnclosedPorch: drop

# %%
homes['EnclosedPorch'].agg(['max','min'])
homes['EnclosedPorch_bin']= pd.cut(homes['EnclosedPorch'],5, labels = False)
homes.groupby('EnclosedPorch_bin').agg(['count','mean','std'])['SalePrice']
# Out:
#                    count           mean           std
# EnclosedPorch_bin
# 0                   1307  184523.798776  80506.185751
# 1                    113  144807.778761  59065.337057
# 2                     38  160739.026316  66311.145085
# 3                      1  265979.000000           NaN
# 4                      1  235000.000000           NaN

# %% [markdown]
# # 3SsnPorch: drop

# %%
homes['3SsnPorch'].agg(['max','min'])
homes['3SsnPorch_bin']= pd.cut(homes['3SsnPorch'],5, labels = False)
homes.groupby('3SsnPorch_bin').agg(['count','mean','std'])['SalePrice']
# Out:
#                count           mean           std
# 3SsnPorch_bin
# 0               1438  180441.118915  79442.814445
# 1                 13  208807.692308  75655.066602
# 2                  6  242019.500000  84630.604875
# 3                  1  143000.000000           NaN
# 4                  2  180500.000000      0.000000

# %% [markdown]
# # ScreenPorch

# %%
homes['ScreenPorch'].agg(['max','min'])
homes['ScreenPorch_bin']= pd.cut(homes['ScreenPorch'],8, labels = False)
homes.groupby('ScreenPorch_bin').agg(['count','mean','median','std'])['SalePrice']
# Out:
#                  count           mean  median            std
# ScreenPorch_bin
# 0                 1347  178808.132888  160000   78268.489361
# 1                   16  161268.750000  150450   54233.159829
# 2                   41  205798.000000  175000   89147.026484
# 3                   34  221538.617647  182500  101689.008049
# 4                   14  187432.857143  174000   58168.116342
# 5                    2  210000.000000  210000   56568.542495
# 6                    4  297500.000000  277500  130671.343454
# 7                    2  253000.000000  253000    4242.640687

# %% [markdown]
# # PoolArea: Drop

# %%
homes['PoolArea'].agg(['max','min'])
homes['PoolArea_bin']= pd.cut(homes['PoolArea'],5, labels = False)
homes.groupby('PoolArea_bin').agg(['count','mean','std'])['SalePrice']
# Out:
#               count           mean            std
# PoolArea_bin
# 0              1453  180404.663455   78168.872519
# 3                 5  312200.000000  245074.886514
# 4                 2  227985.000000   66446.824228
