# %%
import pandas as pd
import numpy as np

# %%
from read_path_module import read_data_relative_path

homes = read_data_relative_path(relative_dataset_path = './data/kaggle/train.csv',
                        data_type='csv'
                       )

homes.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %%
# homes = pd.read_csv('train.csv')

# %%
homes.columns.values.reshape(-1,1)
# Out:
# array([['Id'],
#        ['MSSubClass'],
#        ['MSZoning'],
#        ['LotFrontage'],
#        ['LotArea'],
#        ['Street'],
#        ['Alley'],
#        ['LotShape'],
#        ['LandContour'],
#        ['Utilities'],
#        ['LotConfig'],
#        ['LandSlope'],
#        ['Neighborhood'],
#        ['Condition1'],
#        ['Condition2'],
#        ['BldgType'],
#        ['HouseStyle'],
#        ['OverallQual'],
#        ['OverallCond'],
#        ['YearBuilt'],
#        ['YearRemodAdd'],
#        ['RoofStyle'],
#        ['RoofMatl'],
#        ['Exterior1st'],
#        ['Exterior2nd'],
#        ['MasVnrType'],
#        ['MasVnrArea'],
#        ['ExterQual'],
#        ['ExterCond'],
#        ['Foundation'],
#        ['BsmtQual'],
#        ['BsmtCond'],
#        ['BsmtExposure'],
#        ['BsmtFinType1'],
#        ['BsmtFinSF1'],
#        ['BsmtFinType2'],
#        ['BsmtFinSF2'],
#        ['BsmtUnfSF'],
#        ['TotalBsmtSF'],
#        ['Heating'],
#        ['HeatingQC'],
# ...

# %%
homes.groupby('MSSubClass').agg(['mean','median','count','std','max','min'])['SalePrice'].sort_values(by='count', ascending = False)
# Out:
#                      mean  median  count            std     max     min
# MSSubClass
# 20          185224.811567  159250    536   78782.189967  611657   35311
# 60          239948.501672  215200    299   86579.909966  755000  129000
# 50          143302.972222  132000    144   54851.983707  410000   37900
# 120         200779.080460  192000     87   58221.490909  392500   99500
# 30           95829.724638   99900     69   24857.110083  163500   34900
# 160         138647.380952  146000     63   34587.542266  239000   75000
# 70          166772.416667  156000     60   58206.545762  359100   40000
# 80          169736.551724  166500     58   38197.808771  345000  107000
# 90          133541.076923  135980     52   27833.249197  206300   82000
# 190         129613.333333  128250     30   35439.097670  228950   55000
# 85          147810.000000  140750     20   19629.942220  198500  123000
# 75          192437.500000  163500     16  100556.762577  475000  101000
# ...

# %% [markdown]
# # MSZoning: (FV & RL) vs. (other)

# %%
homes.groupby('MSZoning').agg(['mean','median','count','std','max','min'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                    mean  median  count           std     max     min
# MSZoning
# FV        214014.061538  205950     65  52369.662067  370878  144152
# RL        191004.994787  174000   1151  80766.341319  755000   39300
# RH        131558.375000  136500     16  35714.118435  200000   76000
# RM        126316.830275  120500    218  48521.689833  475000   37900
# C (all)    74528.000000   74700     10  33791.092031  133900   34900

# %%
cat = 'MSZoning'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')

# %% [markdown]
# # Street: drop

# %%
homes.groupby('Street').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='count', ascending = False)
# Out:
#                  mean  median  count           std
# Street
# Pave    181130.538514  163000   1454  79446.597317
# Grvl    130190.500000  114250      6  65446.253991

# %% [markdown]
# # Alley: drop or group: (No alley & Pave) vs Grvl

# %%
homes.Alley.unique()
# Out:
# array(['No Alley', 'Grvl', 'Pave'], dtype=object)

# %%
homes.Alley =homes.Alley.str.replace(' no alley','No Alley')

# %%
homes.groupby('Alley').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='count', ascending = False)
# Out:
#                    mean  median  count           std
# Alley
# No Alley  183452.131483  165000   1369  80667.145180
# Grvl      122219.080000  119500     50  34780.780734
# Pave      168000.585366  172500     41  38370.375243

# %% [markdown]
# # LotShape: Reg vs IR

# %%
homes.groupby('LotShape').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='count', ascending = False)
####    Group Reg vs. IR: IR seems to be of greater value
# Out:
#                    mean  median  count           std
# LotShape
# Reg       164754.818378  146000    925  69673.427215
# IR1       206101.665289  189000    484  85858.489559
# IR2       239833.365854  221000     41  99669.427362
# IR3       216036.500000  203570     10  82540.334855

# %%
cat = 'LotShape'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')

# %% [markdown]
# # LandContour: drop or group: Lvl vs. (HLS & Low) vs. Bank

# %%
homes.groupby('LandContour').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='count', ascending = False)
# Out:
#                       mean  median  count            std
# LandContour
# Lvl          180183.746758  162900   1311   78463.567918
# Bnk          143104.079365  139400     63   49361.244074
# HLS          231533.940000  222250     50  101790.139741
# Low          203661.111111  190000     36   83935.353620

# %%
cat = 'LandContour'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')

# %% [markdown]
# # Utilities: drop

# %%
homes.groupby('Utilities').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='count', ascending = False)
# Out:
#                    mean  median  count           std
# Utilities
# AllPub     180950.95682  163000   1459  79461.599814
# NoSeWa     137500.00000  137500      1           NaN

# %% [markdown]
# # LotConfig: (CulDSac & FR) vs else

# %%
homes.groupby('LotConfig').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                     mean    median  count           std
# LotConfig
# CulDSac    223854.617021  199262.0     94  93117.546586
# FR3        208475.000000  195450.0      4  78379.222374
# Corner     181623.425856  160000.0    263  84466.041222
# FR2        177934.574468  165000.0     47  62788.926829
# Inside     176938.047529  159697.5   1052  76426.805787

# %%
cat = 'LotConfig'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')

# %% [markdown]
# # LandSlope: Discuss

# %%
homes.groupby('LandSlope').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='count', ascending = False)
# Out:
#                     mean  median  count           std
# LandSlope
# Gtl        179956.799566  161875   1382  78669.369151
# Mod        196734.138462  186700     65  92375.358116
# Sev        204379.230769  185000     13  86729.922409

# %%
cat = 'LandSlope'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')

# %% [markdown]
# # Condition1: else vs (RRAe, Feedr, Artery)

# %%
homes.groupby('Condition1').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='median', ascending = False)
# Out:
#                      mean  median  count           std
# Condition1
# RRNn        212400.000000  214000      5  93823.238060
# PosA        225875.000000  212500      8  52348.932313
# PosN        215184.210526  200000     19  65256.536609
# RRNe        190750.000000  190750      2   5303.300859
# RRAn        184396.615385  171495     26  66177.922070
# Norm        184495.492063  166500   1260  81256.980125
# RRAe        138400.000000  142500     11  24030.813553
# Feedr       142475.481481  140000     81  42157.290117
# Artery      135091.666667  119550     48  66226.660548

# %%
cat = 'Condition1'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Condition2: drop

# %%
homes.groupby('Condition2').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='median', ascending = False)
# Out:
#                      mean  median  count            std
# Condition2
# PosA        325000.000000  325000      1            NaN
# PosN        284875.000000  284875      2  141598.132933
# RRAe        190000.000000  190000      1            NaN
# Norm        181169.405536  163500   1445   79337.735547
# RRAn        136905.000000  136905      1            NaN
# Feedr       121166.666667  127500      6   33544.994659
# Artery      106500.000000  106500      2   16263.455967
# RRNn         96750.000000   96750      2   39951.533137

# %% [markdown]
# # BldgType: (1Fam & TwnhsE) vs else

# %%
homes.groupby('BldgType').agg(['mean','median','count','std','max','min'])['SalePrice'].sort_values(by='count', ascending = False)
# Out:
#                    mean  median  count           std     max    min
# BldgType
# 1Fam      185763.807377  167900   1220  82648.502922  755000  34900
# TwnhsE    181959.342105  172200    114  60626.108918  392500  75500
# Duplex    133541.076923  135980     52  27833.249197  206300  82000
# Twnhs     135911.627907  137500     43  41013.222080  230000  75000
# 2fmCon    128432.258065  127500     31  35458.545158  228950  55000

# %%
cat = 'BldgType'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')

# %% [markdown]
# # HouseStyle: (2.5fin & 2story) vs. (1s, Slvl) vs. rest?

# %%
homes.groupby('HouseStyle').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                      mean  median  count            std
# HouseStyle
# 2.5Fin      220000.000000  194000      8  118211.976671
# 2Story      210051.764045  190000    445   87339.213570
# 1Story      175985.477961  154750    726   77055.715011
# SLvl        166703.384615  164500     65   38305.161339
# 2.5Unf      157354.545455  133900     11   63934.128032
# 1.5Fin      143116.740260  132000    154   54277.941119
# SFoyer      135074.486486  135960     37   30480.898192
# 1.5Unf      110150.000000  111250     14   19036.473090

# %%
cat = 'HouseStyle'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')

# %%
homes.SalePrice.agg(['mean','std','median'])
######### Maybe do not need to differenciate by Condition
# Out:
# mean      180921.195890
# std        79442.502883
# median    163000.000000
# Name: SalePrice, dtype: float64

# %%
# Out:
# mean      180921.195890
# median    163000.000000
# std        79442.502883
# Name: SalePrice, dtype: float64

# %%
x = homes[homes['HouseStyle'] != '2.5Fin']
y = x[x['HouseStyle'] != '2Story']
y.SalePrice.agg(['mean','median','std'])
# Out:
# mean      167737.746773
# median    147500.000000
# std        71607.082668
# Name: SalePrice, dtype: float64

# %% [markdown]
# # Overall Qual: high v med v low?

# %%
homes.groupby('OverallQual').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                       mean  median  count            std
# OverallQual
# 10           438588.388889  432390     18  159785.491058
# 9            367513.023256  345000     43   81278.174849
# 8            274735.535714  269750    168   63898.902253
# 7            207716.423197  200141    319   44466.259414
# 6            161603.034759  160000    374   36090.182933
# 5            133523.347607  133000    397   27107.330927
# 4            108420.655172  108000    116   29022.003886
# 3             87473.750000   86250     20   24688.567399
# 2             51770.333333   60000      3   14254.200796
# 1             50150.000000   50150      2   15344.217152

# %%
homes.SalePrice.agg(['mean','median','std'])
# Out:
# mean      180921.195890
# median    163000.000000
# std        79442.502883
# Name: SalePrice, dtype: float64

# %% [markdown]
# # OverallCond:

# %%
import matplotlib.pyplot as plt


homes.groupby('OverallCond').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='mean', ascending = False)
####### no trend?????
# Out:
#                       mean  median  count            std
# OverallCond
# 9            216004.545455  176200     22   96485.974689
# 5            203146.914738  185000    821   85117.319416
# 7            158145.487805  145000    205   53468.189431
# 8            155651.736111  142500     72   52375.144681
# 6            153961.591270  142750    252   60737.969824
# 2            141986.400000   85000      5  141342.813488
# 4            120438.438596  115000     57   38922.525907
# 3            101929.400000   89500     25   44852.490403
# 1             61000.000000   61000      1            NaN

# %%
homes.groupby('OverallCond').agg(['mean','median'])['SalePrice'].sort_values(by='OverallCond', ascending = True).plot.bar(color=['b','g'])

# %% [markdown]
# # RoofMatl: drop

# %%
homes.groupby('RoofMatl').agg(['mean','median','count','std'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                    mean  median  count            std
# RoofMatl
# WdShngl   390250.000000  332500      6  206969.019421
# Membran   241500.000000  241500      1            NaN
# WdShake   241400.000000  242000      5   36218.779659
# Tar&Grv   185406.363636  167000     11   65430.141720
# Metal     180000.000000  180000      1            NaN
# CompShg   179803.679219  162000   1434   77722.388636
# ClyTile   160000.000000  160000      1            NaN
# Roll      137000.000000  137000      1            NaN

# %% [markdown]
# # Roofstyle: drop?

# %%
homes.groupby('RoofStyle').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
# Out:
#                     mean  median  count            std     min     max
# RoofStyle
# Shed       225000.000000  225000      2   49497.474683  190000  260000
# Flat       194690.000000  185000     13   62522.963515   82000  274970
# Hip        218876.933566  176500    286  111549.603563   55000  745000
# Mansard    180568.428571  175000      7   58057.624627  100000  265979
# Gable      171483.956179  160000   1141   66331.237296   34900  755000
# Gambrel    148909.090909  139000     11   67013.527807   40000  259500

# %%
cat = 'RoofStyle'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')

# %% [markdown]
# # Exterior1st: (imstucc, stone, cementbd, vinylsd) vs. ....

# %%
homes.groupby('Exterior1st').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
# Out:
#                       mean    median  count            std     min     max
# Exterior1st
# ImStucc      262000.000000  262000.0      1            NaN  262000  262000
# Stone        258500.000000  258500.0      2   40305.086528  230000  287000
# CemntBd      231690.655738  236500.0     61  120575.621318   75000  556581
# VinylSd      213732.900971  200000.0    515   80646.975785   37900  611657
# Plywood      175942.379630  167450.0    108   49497.383293   82500  345000
# BrkFace      194573.000000  165750.0     50   82841.914370   40000  430000
# HdBoard      163077.450450  149900.0    222   66305.714164   83000  755000
# Stucco       162990.000000  144000.0     25   83307.246529   58500  381000
# MetalSd      149422.177273  139000.0    220   54776.408990   62383  392000
# Wd Sdng      149841.645631  138943.5    206   71130.448152   34900  745000
# WdShing      150655.076923  128700.0     26   72507.530741   87000  385000
# ...

# %% [markdown]
# # Exterior2nd: (other, cmentbd, vinylsd, imstucc, stone) vs (plywood,brkface, hdboard, )  vs  (rest)

# %%
homes.groupby('Exterior2nd').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
##################     how to cluster large groups
# Out:
#                       mean    median  count            std     min     max
# Exterior2nd
# Other        319000.000000  319000.0      1            NaN  319000  319000
# CmentBd      230093.833333  238750.0     60  116140.396221   75000  556581
# VinylSd      214432.460317  200070.5    504   80708.309670   37900  611657
# ImStucc      252070.000000  187600.0     10  193176.672447   88000  745000
# Stone        158224.800000  177000.0      5   63533.067573   90000  230000
# Plywood      168112.387324  160750.0    142   46955.744372   76500  320000
# BrkFace      195818.000000  160000.0     25   95097.551756   40000  430000
# HdBoard      167661.565217  155000.0    207   70061.078357   83000  755000
# Brk Cmn      126714.285714  147000.0      7   38693.084161   60000  155000
# Stucco       155905.153846  142000.0     26   74862.492410   58500  381000
# AsphShn      138000.000000  139000.0      3   37509.998667  100000  175000
# ...

# %% [markdown]
# # MasVnrType: Stone v BrkFace v (none & Brkcmn)

# %%
homes.groupby('MasVnrType').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
# Out:
#                      mean  median  count           std     min     max
# MasVnrType
# Stone       265583.625000  246839    128  99940.156577  119000  611657
# BrkFace     204691.871910  181000    445  81214.293554   75000  755000
# None        156221.891204  143000    864  60708.262798   34900  745000
# BrkCmn      146318.066667  139000     15  46187.583632   89471  277000

# %%
cat = 'MasVnrType'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')

# %% [markdown]
# # ExterQual: (ex & gd) v rest

# %%
homes.groupby('ExterQual').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
# Out:
#                     mean    median  count            std     min     max
# ExterQual
# Ex         367360.961538  364606.5     52  116401.264200  160000  755000
# Gd         231633.510246  220000.0    488   71188.873899   52000  745000
# TA         144341.313466  139450.0    906   42471.815703   34900  381000
# Fa          87985.214286   82250.0     14   39826.918794   39300  200000

# %%
cat = 'ExterQual'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # ExterQual: drop?

# %%
homes.groupby('ExterCond').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
########## no need to differentiate
# Out:
#                     mean  median  count            std     min     max
# ExterCond
# TA         184034.896256  167370   1282   79806.257233   34900  755000
# Ex         201333.333333  161000      3  109235.220205  118000  325000
# Gd         168897.568493  151250    146   72608.303632   68400  625000
# Fa         102595.142857   95750     28   40094.383940   39300  169500
# Po          76500.000000   76500      1            NaN   76500   76500

# %%
cat = 'ExterCond'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # Foundation: Pconc v (wood, cblock) v (stone, brktil, slab)

# %%
homes.groupby('Foundation').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
# Out:
#                      mean  median  count           std     min     max
# Foundation
# PConc       225230.442040  205000    647  86865.977283   78000  755000
# Wood        185666.666667  164000      3  56695.090910  143000  250000
# CBlock      149805.714511  141500    634  48295.041759   34900  402861
# Stone       165959.166667  126500      6  78557.704413  102776  266500
# BrkTil      132291.075342  125250    146  54592.393032   37900  475000
# Slab        107365.625000  104150     24  34213.980939   39300  198500

# %%
cat = 'Foundation'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # BsmtCond: basement v no basement

# %%
homes.BsmtCond = homes.BsmtCond.str.replace('no basement', 'No Basement')

# %%
homes.BsmtCond.unique()
# Out:
# array(['TA', 'Gd', 'No Basement', 'Fa', 'Po'], dtype=object)

# %%
homes.groupby('BsmtCond').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
#####        might not be necessary: refer to R hist plot

######        maybe just basement or no basement
# Out:
#                       mean  median  count           std     min     max
# BsmtCond
# Gd           213599.907692  193879     65  72663.155026  119000  465000
# TA           183632.620900  165000   1311  79515.388449   34900  755000
# Fa           121809.533333  118500     45  43467.796975   55000  265979
# No Basement  105652.891892  101800     37  29278.694797   39300  198500
# Po            64000.000000   64000      2   4242.640687   61000   67000

# %%
cat = 'BsmtCond'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # BsmtQual: no basement v (TA & fa) v gd v ex?

# %%
homes.BsmtQual = homes.BsmtQual.fillna('no basement')


homes.groupby('BsmtQual').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
# Out:
#                       mean  median  count            std     min     max
# BsmtQual
# Ex           327041.041322  318000    121  113563.237392  123500  755000
# Gd           202688.478964  192070    618   58092.364284   75500  538000
# TA           140759.818182  135500    649   43483.265311   34900  475000
# Fa           115692.028571  112000     35   34469.667278   61000  206900
# no basement  105652.891892  101800     37   29278.694797   39300  198500

# %%
cat = 'BsmtQual'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # BsmtExposure: dummy all

# %%
homes.BsmtExposure = homes.BsmtExposure.fillna('no basement')


homes.groupby('BsmtExposure').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='median', ascending = False)
################ Discuss
# Out:
#                        mean  median  count            std    min     max
# BsmtExposure
# Gd            257689.805970  226975    134  118923.672583  61000  755000
# Av            206643.420814  185850    221   88655.504849  35311  745000
# Mn            192789.657895  182450    114   77335.442652  78000  475000
# No            165652.295908  154000    953   60695.724915  34900  501837
# no basement   107938.342105  104025     38   32133.440664  39300  198500

# %%
cat = 'BsmtExposure'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # BsmtFinType1: ?

# %%
homes.BsmtFinType1 = homes.BsmtFinType1.fillna('no basement')


homes.groupby('BsmtFinType1').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
####### refer to r plot: GLQ vs. No basement   VS. Everything Else
# Out:
#                        mean  median  count           std    min     max
# BsmtFinType1
# GLQ           235413.720096  213750    418  93215.613258  80000  755000
# Unf           170670.576744  161750    430  72577.080129  37900  582933
# ALQ           161573.068182  149250    220  50821.277231  81000  538000
# LwQ           151852.702703  139000     74  50796.987083  75500  301000
# BLQ           149493.655405  139100    148  47327.292126  35311  359100
# Rec           146889.248120  142000    133  45190.118879  34900  381000
# no basement   105652.891892  101800     37  29278.694797  39300  198500

# %%
cat = 'BsmtFinType1'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # BsmtFinType2: basement v no basement?

# %%
homes.BsmtFinType2 = homes.BsmtFinType2.fillna('No Basement')

homes.groupby('BsmtFinType2').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
######### maybe unecessary

######### maybe no basement vs with
# Out:
#                        mean  median  count            std     min     max
# BsmtFinType2
# ALQ           209942.105263  174900     19  104764.743411  123500  555000
# Unf           184694.690287  167000   1256   81275.313909   34900  755000
# GLQ           180982.142857  203125     14   64573.040359   75500  270000
# Rec           164917.129630  148750     54   59183.277020   85000  402000
# LwQ           164364.130435  154000     46   43255.035241   88000  287000
# BLQ           151101.000000  143000     33   41611.305388   62383  271900
# No Basement   110346.236842  104025     38   40879.307312   39300  284000

# %%
cat = 'BsmtFinType2'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # Heating: drop

# %%
homes.groupby('Heating').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                   mean  median  count           std     min     max
# Heating
# GasA     182021.195378  164500   1428  79262.873587   34900  755000
# GasW     166632.166667  134950     18  78547.575324   82000  375000
# OthW     125750.000000  125750      2   5303.300859  122000  129500
# Wall      92100.000000   91450      4   4509.988914   87500   98000
# Grav      75271.428571   79000      7  28066.570524   37900  121000
# Floor     72500.000000   72500      1           NaN   72500   72500

# %% [markdown]
# # HeatingQC:    Ex   v.   middle    v.  ( poor & fair)

# %%
homes.groupby('HeatingQC').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
###########     (TA & Fa & po) vs gd vs EX
# Out:
#                     mean  median  count           std    min     max
# HeatingQC
# Ex         214914.429150  194700    741  87469.704503  66500  755000
# Gd         156858.871369  152000    241  52923.920003  52000  395000
# TA         142362.876168  135000    428  47226.485663  34900  375000
# Fa         123919.489796  123500     49  50306.618996  37900  235000
# Po          87000.000000   87000      1           NaN  87000   87000

# %%
cat = 'HeatingQC'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # Electrical:   Sbrkr    v  rest

# %%
homes.groupby('Electrical').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                      mean  median  count           std    min     max
# Electrical
# SBrkr       186825.113193  170000   1334  79856.458326  37900  755000
# FuseA       122196.893617  121250     94  37511.376615  34900  239000
# FuseF       107675.444444  115000     27  30636.507376  39300  169500
# FuseP        97333.333333   82000      3  34645.827070  73000  137000
# Mix          67000.000000   67000      1           NaN  67000   67000

# %% [markdown]
# # Kitchen Qual: Ex v Gd v  ( Ta & Fa)

# %%
homes.groupby('KitchenQual').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
########### (FA & TA)   vs    GD  vds ex?
# Out:
#                       mean  median  count            std    min     max
# KitchenQual
# Ex           328554.670000  316750    100  120862.942573  86000  755000
# Gd           212116.023891  201400    586   64020.176702  79000  625000
# TA           139962.511565  137000    735   38896.280336  34900  375000
# Fa           105565.205128  115000     39   36004.254037  39300  200000

# %%
cat = 'KitchenQual'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # Functional: drop

# %%
homes.groupby('Functional').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
############ maybe unecessary
# Out:
#                      mean  median  count            std     min     max
# Functional
# Typ         183429.147059  165500   1360   80017.959658   34900  755000
# Mod         168393.333333  137900     15  118938.666467   55000  538000
# Maj1        153948.142857  140750     14   64503.775815   60000  315000
# Min1        146385.483871  139000     31   38089.572487   82000  256000
# Min2        144240.647059  140000     34   41215.354652   87000  316600
# Sev         129000.000000  129000      1            NaN  129000  129000
# Maj2         85800.000000   85000      5   27086.897201   52000  115000

# %%
cat = 'Functional'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # FireplaceQu: no fireplace v poor v else

# %%
homes.FireplaceQu.unique()
# Out:
# array([nan, 'TA', 'Gd', 'Fa', 'Ex', 'Po'], dtype=object)

# %%
homes.FireplaceQu = homes.FireplaceQu.fillna('No Fireplace')

homes.groupby('FireplaceQu').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
############    prob na vs existing
##############    na & poor   vs  else
# Out:
#                        mean  median  count            std     min     max
# FireplaceQu
# Ex            337712.500000  314250     24  123611.471764  130500  755000
# Gd            226351.415789  206950    380   91123.148369   90350  611657
# TA            205723.488818  187500    313   71367.028772   82500  745000
# Fa            167298.484848  158000     33   34287.717564  117000  262000
# No Fireplace  141331.482609  135000    690   44389.786884   34900  342643
# Po            129764.150000  131500     20   31080.842115   60000  172000

# %%
cat = 'FireplaceQu'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # GarageType: (built in & attached) v (basemement,2type,detached, carport) v no

# %%
homes.GarageType = homes.GarageType.fillna('no garage')




homes.groupby('GarageType').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                      mean  median  count            std    min     max
# GarageType
# BuiltIn     254751.738636  227500     88  102230.854394  91000  582933
# Attchd      202892.656322  185000    870   77146.621778  60000  755000
# Basment     160570.684211  148000     19   63967.283574  55993  359100
# 2Types      151283.333333  159000      6   34917.068415  87000  186700
# Detchd      134091.162791  129500    387   41391.549953  35311  475000
# CarPort     109962.111111  108000      9   24638.183681  82000  164900
# no garage   103317.283951  100000     81   32815.023389  34900  200500

# %%
cat = 'GarageType'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # Garage Finish: dummy all

# %%
homes.GarageFinish = homes.GarageFinish.fillna('No Garage')
homes.groupby('GarageFinish').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                        mean  median  count           std    min     max
# GarageFinish
# Fin           240052.690341  215000    352  96960.593232  82500  755000
# RFn           202068.869668  190000    422  63536.222518  68400  582933
# Unf           142156.423140  135000    605  46498.528211  35311  475000
# No Garage     103317.283951  100000     81  32815.023389  34900  200500

# %%
cat = 'GarageFinish'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # GarageQual: poor & no garage v  rest

# %%
homes.GarageQual = homes.GarageQual.fillna('No Garage')

homes.groupby('GarageQual').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                      mean  median  count            std     min     max
# GarageQual
# Ex          241000.000000  127500      3  202680.166765  120500  475000
# Gd          215860.714286  209115     14   74126.739021   90350  325000
# TA          187489.836003  170000   1311   78774.948567   35311  755000
# Fa          123573.354167  115000     48   42971.440985   64500  256000
# No Garage   103317.283951  100000     81   32815.023389   34900  200500
# Po          100166.666667   96500      3   35143.752408   67000  137000

# %%
cat = 'GarageQual'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # GarageCond: no garage v rest

# %%
homes.groupby('GarageCond').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                      mean  median  count           std     min     max
# GarageCond
# TA          187885.735294  170000   1326  79103.322640   35311  755000
# Gd          179930.000000  148000      9  64769.318354  118500  302000
# Ex          124000.000000  124000      2   4949.747468  120500  127500
# Fa          114654.028571  114504     35  36420.903588   40000  220000
# Po          108500.000000  108000      7  22662.377045   67000  137000
# no garage   103317.283951  100000     81  32815.023389   34900  200500

# %%
cat = 'GarageCond'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %% [markdown]
# # Pavedrive: Y v (P & N)

# %%
homes.groupby('PavedDrive').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                      mean  median  count           std    min     max
# PavedDrive
# Y           186433.973881  168500   1340  79665.503047  35311  755000
# P           132330.000000  132250     30  33503.030228  79500  215000
# N           115039.122222  111000     90  44352.523309  34900  265979

# %%
cat = 'PavedDrive'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %%
import seaborn as sns

# %%
homes['saleprice_bin']= pd.cut(homes['SalePrice'],30, labels = False)

# %%
homes.groupby('PavedDrive').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                      mean  median  count           std    min     max
# PavedDrive
# Y           186433.973881  168500   1340  79665.503047  35311  755000
# P           132330.000000  132250     30  33503.030228  79500  215000
# N           115039.122222  111000     90  44352.523309  34900  265979

# %%
cat = 'PavedDrive'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)



####### Unnecessary to differentiate/ drop

# %%
homes.PoolQC =homes.PoolQC.fillna('no pool')
homes.groupby('PoolQC').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                   mean  median  count            std     min     max
# PoolQC
# Ex       490000.000000  490000      2  360624.458405  235000  745000
# Fa       215500.000000  215500      2   48790.367902  181000  250000
# Gd       201990.000000  171000      3   63441.392639  160000  274970
# no pool  180404.663455  162900   1453   78168.872519   34900  755000

# %%
cat = 'PoolQC'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin')

# %% [markdown]
# # Fence: no fence v fence

# %%
homes.Fence =homes.Fence.fillna('no fence')

homes.groupby('Fence').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                    mean  median  count           std     min     max
# Fence
# no fence  187596.837998  173000   1179  81656.497075   35311  755000
# GdPrv     178927.457627  167500     59  56757.237563  108000  475000
# MnPrv     148751.089172  137450    157  66096.069463   40000  745000
# GdWo      140379.314815  138750     54  53592.585059   34900  381000
# MnWw      134286.363636  130000     11  21781.805376  110000  187000

# %%
cat = 'Fence'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)



###### no fence & Good fence    vs.    else?

# %% [markdown]
# # MiscFeature: drop

# %%
homes.MiscFeature =homes.MiscFeature.fillna('none')

homes.groupby('MiscFeature').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
####### probably do not need
# Out:
#                       mean  median  count           std     min     max
# MiscFeature
# TenC         250000.000000  250000      1           NaN  250000  250000
# none         182046.410384  164250   1406  80084.136570   34900  755000
# Gar2         170750.000000  170750      2  27223.611076  151500  190000
# Shed         151187.612245  144000     49  51642.728056   55993  277000
# Othr          94000.000000   94000      2  55154.328933   55000  133000

# %% [markdown]
# # Salecondition: (adjland & abnormal & family) v (alloca v Normal)  v  partial

# %% [markdown]
# # SaleType: New v else

# %%
homes.groupby('SaleType').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                    mean  median  count            std     min     max
# SaleType
# New       274945.418033  247453    122  103239.582158  113000  611657
# Con       269600.000000  269600      2   76933.217793  215200  324000
# CWD       210600.000000  188750      4   86421.486526  136000  328900
# ConLI     200390.000000  125000      5  145282.519595  110000  451950
# WD        173401.836622  158000   1267   71129.686245   34900  755000
# COD       143973.255814  139000     43   47098.294314   60000  287000
# ConLw     143700.000000  144000      5   67291.901444   60000  212000
# ConLD     138780.888889  140000      9   53876.560647   79900  235128
# Oth       119850.000000  116050      3   28441.035495   93500  150000

# %%
homes.groupby('SaleCondition').agg(['mean','median','count','std','min','max'])['SalePrice'].sort_values(by='mean', ascending = False)
# Out:
#                         mean  median  count            std     min     max
# SaleCondition
# Partial        272291.752000  244600    125  103696.404119  113000  611657
# Normal         175202.219533  160000   1198   69713.636280   39300  755000
# Alloca         167377.416667  148145     12   84460.527502   55993  359100
# Family         149600.000000  140500     20   47820.002421   82500  259000
# Abnorml        146526.623762  130000    101   82796.213395   34900  745000
# AdjLand        104125.000000  104000      4   26135.464411   81000  127500

# %%
cat = 'SaleCondition'

homesGrid = sns.FacetGrid(homes, row= cat, hue= cat, palette="Set1", height  = 3, aspect = 4 )

homesGrid.map(sns.distplot,'saleprice_bin', kde = False)

# %%
homes.to_csv('homes.csv')
