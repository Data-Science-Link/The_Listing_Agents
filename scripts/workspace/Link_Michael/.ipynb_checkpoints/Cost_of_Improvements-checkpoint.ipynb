# %%
import pandas as pd

# %% [markdown]
# ### Import cost of improvements csv

# %%
from read_path_module import read_data_relative_path

cost_of_improvements = read_data_relative_path(relative_dataset_path = './data/kaggle/created/cost_of_improvements.csv',
                        data_type='csv'
                       )

# %% [markdown]
# ### Show example of dataset

# %%
# Show example of table
cost_of_improvements[cost_of_improvements.Cost.notnull()].head(20)
# Out:
#         Variable                                        Description  \
# 21     RoofStyle                                       Type of roof
# 22      RoofMatl                                      Roof material
# 31      BsmtCond    Evaluates the general condition of the basement
# 33  BsmtFinType1                   Rating of basement finished area
# 34    BsmtFinSF1                        Type 1 finished square feet
# 35  BsmtFinType2  Rating of basement finished area (if multiple ...
# 36    BsmtFinSF2                        Type 2 finished square feet
# 37     BsmtUnfSF            Unfinished square feet of basement area
# 39       Heating                                    Type of heating
# 40     HeatingQC                      Heating quality and condition
# 41    CentralAir                           Central air conditioning
# 45  LowQualFinSF      Low quality finished square feet (all floors)
# 46     GrLivArea       Above grade (ground) living area square feet
# 47  BsmtFullBath                            Basement full bathrooms
# 48  BsmtHalfBath                            Basement half bathrooms
# 49      FullBath                         Full bathrooms above grade
# 50      HalfBath                             Half baths above grade
# 53   KitchenQual                                    Kitchen quality
# 57   FireplaceQu                                  Fireplace quality
# 60  GarageFinish                      Interior finish of the garage
#
#    Upgradable                                    Cost  \
# 21          y                                    8022
# 22          y                                    8022
# 31          y                                   30000
# 33          y             37.5 / unfinished square ft
# 34          y             37.5 / unfinished square ft
# 35          y             37.5 / unfinished square ft
# 36          y             37.5 / unfinished square ft
# 37          y             37.5 / unfinished square ft
# 39          y                                    7000
# 40          y                                    7000
# 41          y                                    5000
# 45          y             37.5 / unfinished square ft
# 46      Tough  2100 to take out non-load bearing wall
# 47          y                                   15000
# 48          y                                   10000
# 49          y                                   25000
# 50          y                                   10000
# 53          y                                   25095
# 57          y                                    1200
# 60          y                                   12500
#
#                                                Source
# 21  https://www.homeadvisor.com/cost/roofing/insta...
# 22  https://www.homeadvisor.com/cost/roofing/insta...
# 31  https://smartasset.com/mortgage/the-average-co...
# 33  https://smartasset.com/mortgage/the-average-co...
# 34  https://smartasset.com/mortgage/the-average-co...
# 35  https://smartasset.com/mortgage/the-average-co...
# 36  https://smartasset.com/mortgage/the-average-co...
# 37  https://smartasset.com/mortgage/the-average-co...
# 39  https://www.fixr.com/costs/gas-central-heating...
# 40  https://www.fixr.com/costs/gas-central-heating...
# 41  https://www.nerdwallet.com/blog/mortgages/cost...
# 45  https://smartasset.com/mortgage/the-average-co...
# 46  https://www.homeadvisor.com/cost/additions-and...
# 47  https://www.angieslist.com/articles/how-much-d...
# 48  https://www.angieslist.com/articles/how-much-d...
# 49        https://www.homeadvisor.com/cost/bathrooms/
# 50  https://www.saniflodepot.com/pages/cost-to-add...
# 53  https://www.homeadvisor.com/cost/kitchens/remo...
# 57  https://www.improvenet.com/r/costs-and-prices/...
# 60  https://www.kompareit.com/homeandgarden/remode...
